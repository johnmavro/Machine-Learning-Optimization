# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms, utils
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import time
import os
import copy
import pickle

from Frank_Wolfe.DFW import *
from Frank_Wolfe.utils import *

# %%
save_stats = True
save_figs = True

# %%
def accuracy(predicted_logits, reference):
    """
    Compute the ratio of correctly predicted labels
    :param predicted_logits: float32 tensor of shape (batch size, num classes)
                        The logits predicted by the model
    :param reference: int64 tensor of shape (batch_size) with the class number
                        Ground-truth labels
    :return: accuracy: float
    """

    labels = torch.argmax(predicted_logits, 1)
    correct_predictions = labels.eq(reference)
    return correct_predictions.sum().float() / correct_predictions.nelement()

# %%
# we download and normalize the datasets

ts = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0,), (1,))])
mnist_trainset = datasets.MNIST('../data', train=True, download=True, transform=ts)
mnist_testset = datasets.MNIST(root='../data', train=False, download=True, transform=ts)

# %%
batch_size = 1000

# we import the dataloaders

dataset_test = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('../data', train=False, download=True, transform=torchvision.transforms.ToTensor()), 
  batch_size=100,
  shuffle=True
)
dataset_train = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('../data', train=True, download=True, transform=torchvision.transforms.ToTensor()),
  batch_size=batch_size,
  shuffle=True
)

# %%
input_size = 28*28
hidden_size = 1500
output_size = 10

# %%
# model architecture definition

class MultiLayerPerceptron(torch.nn.Module):
    
    # fully connected neural network with 2 hidden layers with 1500 neurons each. We use ReLU activation functions
    
    def __init__(self):
        super(MultiLayerPerceptron,self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.relu = nn.ReLU()
        self.fc_in = nn.Linear(self.input_size,self.hidden_size,bias=True) # fully connected input_layer
        self.fc_hid_1 = nn.Linear(self.hidden_size,self.hidden_size,bias=True) # fully connected hidden_layer_1
        self.fc_hid_2 = nn.Linear(self.hidden_size,self.hidden_size,bias=True) # fully connected hidden_layer_2
        self.fc_out = nn.Linear(self.hidden_size,self.output_size,bias=True)
    
    def forward(self,x):
        batch_size = x.shape[0]
        x = x.view(batch_size, self.input_size)
        x = self.relu(self.fc_in(x))
        x = self.relu(self.fc_hid_1(x))
        x = self.relu(self.fc_hid_2(x))
        x = self.fc_out(x)
        return x

# %%
#initialize the model
mlp = MultiLayerPerceptron()

# %%
learning_rate = 0.001

cross_entropy = nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(mlp.parameters(), lr=learning_rate)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
def train_model(model, dataset_train, dataset_test, optimizer, criterion, epochs, scheduler=None, lr_decrease=True):
    """
    The function is used to train the neural network
    :param model: <class '__main__.MultiLayerPerceptron'>
                    The model we wish to train
    :param dataset_train: <class 'torch.utils.data.dataloader.DataLoader'>
                    The train pytorch dataloader
    :param dataset_test: <class 'torch.utils.data.dataloader.DataLoader'>
                    The test pytorch dataloader
    :param optimizer: <class 'torch.optim.sgd.SGD'>
                    The used pytorch optimizer
    :param criterion: <class 'torch.nn.modules.loss.CrossEntropyLoss'>
                    The loss used during the training
    :param epochs: int
                    The number of epochs
    :return: train losses, accuracies: lists of training losses and test accuracies respectively
    """
    train_losses = []
    accuracies = []
    
    for epoch in range(epochs): # loop over the dataset multiple times
        epoch_loss = 0.0 
        model.train()
        running_loss = 0
        n_steps =0
        for batch_x,batch_y in dataset_train:
            n_steps = n_steps+1
            # batch_x,batch_y = batch_x.to(device),batch_y.to(device)

            #Get output and evaluate with loss function
            predictions = model(batch_x)
            loss = criterion(predictions,batch_y)
            running_loss += loss.item() * len(batch_y)
    
            #Initialize optimizer
            optimizer.zero_grad()
            loss.backward()

            #Update the network
            optimizer.step(lambda: float(loss))
            
        running_loss = running_loss / n_steps
        train_losses.append(running_loss)
        
        #Test the quality on the test set
        model.eval()
        accuracies_test = []
        
        for batch_x, batch_y in dataset_test:
            # batch_x, batch_y = batch_x.to(device), batch_y.to(device)

            # Evaluate the network (forward pass)
            prediction = model(batch_x)
            accuracies_test.append(accuracy(prediction, batch_y))
    
        print("Epoch {} | Test accuracy: {:.5f}".format(epoch, sum(accuracies_test).item()/len(accuracies_test)))
        
        accuracies.append(sum(accuracies_test).item()/len(accuracies_test))
    return train_losses, accuracies

# %%
num_epochs = 200

start = time.time()

#train using DFW
train_losses, accuracies_test = train_model(mlp, dataset_train, dataset_test, optimizer, cross_entropy, num_epochs)

end = time.time()
print('\n')
print('The total time spent is', end - start)
# Out:
# Epoch 0 | Test accuracy: 0.10080
# Epoch 1 | Test accuracy: 0.11070
# Epoch 2 | Test accuracy: 0.12280
# Epoch 3 | Test accuracy: 0.13810
# Epoch 4 | Test accuracy: 0.15580
# Epoch 5 | Test accuracy: 0.17550
# Epoch 6 | Test accuracy: 0.19720
# Epoch 7 | Test accuracy: 0.22230
# Epoch 8 | Test accuracy: 0.24290
# Epoch 9 | Test accuracy: 0.26380
# Epoch 10 | Test accuracy: 0.28350
# Epoch 11 | Test accuracy: 0.30360
# Epoch 12 | Test accuracy: 0.32030
# Epoch 13 | Test accuracy: 0.33840
# Epoch 14 | Test accuracy: 0.35030
# Epoch 15 | Test accuracy: 0.36010
# Epoch 16 | Test accuracy: 0.37080
# Epoch 17 | Test accuracy: 0.38180
# Epoch 18 | Test accuracy: 0.39270
# Epoch 19 | Test accuracy: 0.40360
# Epoch 20 | Test accuracy: 0.41570
# Epoch 21 | Test accuracy: 0.42880
# Epoch 22 | Test accuracy: 0.44290
# Epoch 23 | Test accuracy: 0.45740
# Epoch 24 | Test accuracy: 0.46970
# Epoch 25 | Test accuracy: 0.48210
# Epoch 26 | Test accuracy: 0.49330
# Epoch 27 | Test accuracy: 0.50100
# Epoch 28 | Test accuracy: 0.50990
# Epoch 29 | Test accuracy: 0.51640
# Epoch 30 | Test accuracy: 0.52310
# Epoch 31 | Test accuracy: 0.53030
# Epoch 32 | Test accuracy: 0.53600
# Epoch 33 | Test accuracy: 0.54080
# Epoch 34 | Test accuracy: 0.54610
# Epoch 35 | Test accuracy: 0.55090
# Epoch 36 | Test accuracy: 0.55620
# Epoch 37 | Test accuracy: 0.56090
# Epoch 38 | Test accuracy: 0.56470
# Epoch 39 | Test accuracy: 0.56860
# Epoch 40 | Test accuracy: 0.57270
# Epoch 41 | Test accuracy: 0.57510
# Epoch 42 | Test accuracy: 0.57770
# Epoch 43 | Test accuracy: 0.58010
# Epoch 44 | Test accuracy: 0.58220
# Epoch 45 | Test accuracy: 0.58510
# Epoch 46 | Test accuracy: 0.58680
# Epoch 47 | Test accuracy: 0.58900
# Epoch 48 | Test accuracy: 0.59020
# Epoch 49 | Test accuracy: 0.59160
# Epoch 50 | Test accuracy: 0.59330
# Epoch 51 | Test accuracy: 0.59530
# Epoch 52 | Test accuracy: 0.59690
# Epoch 53 | Test accuracy: 0.59840
# Epoch 54 | Test accuracy: 0.59850
# Epoch 55 | Test accuracy: 0.60020
# Epoch 56 | Test accuracy: 0.60090
# Epoch 57 | Test accuracy: 0.60200
# Epoch 58 | Test accuracy: 0.60380
# Epoch 59 | Test accuracy: 0.60580
# Epoch 60 | Test accuracy: 0.60770
# Epoch 61 | Test accuracy: 0.60870
# Epoch 62 | Test accuracy: 0.60990
# Epoch 63 | Test accuracy: 0.61200
# Epoch 64 | Test accuracy: 0.61280
# Epoch 65 | Test accuracy: 0.61380
# Epoch 66 | Test accuracy: 0.61530
# Epoch 67 | Test accuracy: 0.61720
# Epoch 68 | Test accuracy: 0.61950
# Epoch 69 | Test accuracy: 0.62080
# Epoch 70 | Test accuracy: 0.62280
# Epoch 71 | Test accuracy: 0.62400
# Epoch 72 | Test accuracy: 0.62530
# Epoch 73 | Test accuracy: 0.62590
# Epoch 74 | Test accuracy: 0.62740
# Epoch 75 | Test accuracy: 0.62920
# Epoch 76 | Test accuracy: 0.63060
# Epoch 77 | Test accuracy: 0.63260
# Epoch 78 | Test accuracy: 0.63550
# Epoch 79 | Test accuracy: 0.63720
# Epoch 80 | Test accuracy: 0.63900
# Epoch 81 | Test accuracy: 0.64070
# Epoch 82 | Test accuracy: 0.64270
# Epoch 83 | Test accuracy: 0.64380
# Epoch 84 | Test accuracy: 0.64590
# Epoch 85 | Test accuracy: 0.64850
# Epoch 86 | Test accuracy: 0.65040
# Epoch 87 | Test accuracy: 0.65350
# Epoch 88 | Test accuracy: 0.65560
# Epoch 89 | Test accuracy: 0.65870
# Epoch 90 | Test accuracy: 0.66100
# Epoch 91 | Test accuracy: 0.66350
# Epoch 92 | Test accuracy: 0.66660
# Epoch 93 | Test accuracy: 0.66890
# Epoch 94 | Test accuracy: 0.67190
# Epoch 95 | Test accuracy: 0.67580
# Epoch 96 | Test accuracy: 0.67710
# Epoch 97 | Test accuracy: 0.68040
# Epoch 98 | Test accuracy: 0.68370
# Epoch 99 | Test accuracy: 0.68620
# Epoch 100 | Test accuracy: 0.68760
# Epoch 101 | Test accuracy: 0.69000
# Epoch 102 | Test accuracy: 0.69160
# Epoch 103 | Test accuracy: 0.69310
# Epoch 104 | Test accuracy: 0.69530
# Epoch 105 | Test accuracy: 0.69900
# Epoch 106 | Test accuracy: 0.70040
# Epoch 107 | Test accuracy: 0.70240
# Epoch 108 | Test accuracy: 0.70420
# Epoch 109 | Test accuracy: 0.70730
# Epoch 110 | Test accuracy: 0.71010
# Epoch 111 | Test accuracy: 0.71260
# Epoch 112 | Test accuracy: 0.71420
# Epoch 113 | Test accuracy: 0.71520
# Epoch 114 | Test accuracy: 0.71800
# Epoch 115 | Test accuracy: 0.72070
# Epoch 116 | Test accuracy: 0.72310
# Epoch 117 | Test accuracy: 0.72560
# Epoch 118 | Test accuracy: 0.72900
# Epoch 119 | Test accuracy: 0.73230
# Epoch 120 | Test accuracy: 0.73550
# Epoch 121 | Test accuracy: 0.73770
# Epoch 122 | Test accuracy: 0.74170
# Epoch 123 | Test accuracy: 0.74520
# Epoch 124 | Test accuracy: 0.74800
# Epoch 125 | Test accuracy: 0.75000
# Epoch 126 | Test accuracy: 0.75250
# Epoch 127 | Test accuracy: 0.75520
# Epoch 128 | Test accuracy: 0.75790
# Epoch 129 | Test accuracy: 0.75990
# Epoch 130 | Test accuracy: 0.76200
# Epoch 131 | Test accuracy: 0.76470
# Epoch 132 | Test accuracy: 0.76690
# Epoch 133 | Test accuracy: 0.76800
# Epoch 134 | Test accuracy: 0.77030
# Epoch 135 | Test accuracy: 0.77160
# Epoch 136 | Test accuracy: 0.77370
# Epoch 137 | Test accuracy: 0.77480
# Epoch 138 | Test accuracy: 0.77710
# Epoch 139 | Test accuracy: 0.77860
# Epoch 140 | Test accuracy: 0.77930
# Epoch 141 | Test accuracy: 0.78200
# Epoch 142 | Test accuracy: 0.78430
# Epoch 143 | Test accuracy: 0.78560
# Epoch 144 | Test accuracy: 0.78810
# Epoch 145 | Test accuracy: 0.78990
# Epoch 146 | Test accuracy: 0.79150
# Epoch 147 | Test accuracy: 0.79280
# Epoch 148 | Test accuracy: 0.79430
# Epoch 149 | Test accuracy: 0.79500
# Epoch 150 | Test accuracy: 0.79560
# Epoch 151 | Test accuracy: 0.79680
# Epoch 152 | Test accuracy: 0.79800
# Epoch 153 | Test accuracy: 0.79910
# Epoch 154 | Test accuracy: 0.80100
# Epoch 155 | Test accuracy: 0.80170
# Epoch 156 | Test accuracy: 0.80300
# Epoch 157 | Test accuracy: 0.80470
# Epoch 158 | Test accuracy: 0.80580
# Epoch 159 | Test accuracy: 0.80750
# Epoch 160 | Test accuracy: 0.80830
# Epoch 161 | Test accuracy: 0.80950
# Epoch 162 | Test accuracy: 0.81050
# Epoch 163 | Test accuracy: 0.81180
# Epoch 164 | Test accuracy: 0.81330
# Epoch 165 | Test accuracy: 0.81460
# Epoch 166 | Test accuracy: 0.81590
# Epoch 167 | Test accuracy: 0.81730
# Epoch 168 | Test accuracy: 0.81810
# Epoch 169 | Test accuracy: 0.81920
# Epoch 170 | Test accuracy: 0.82050
# Epoch 171 | Test accuracy: 0.82130
# Epoch 172 | Test accuracy: 0.82220
# Epoch 173 | Test accuracy: 0.82400
# Epoch 174 | Test accuracy: 0.82540
# Epoch 175 | Test accuracy: 0.82620
# Epoch 176 | Test accuracy: 0.82740
# Epoch 177 | Test accuracy: 0.82880
# Epoch 178 | Test accuracy: 0.82980
# Epoch 179 | Test accuracy: 0.82990
# Epoch 180 | Test accuracy: 0.83140
# Epoch 181 | Test accuracy: 0.83240
# Epoch 182 | Test accuracy: 0.83340
# Epoch 183 | Test accuracy: 0.83400
# Epoch 184 | Test accuracy: 0.83470
# Epoch 185 | Test accuracy: 0.83550
# Epoch 186 | Test accuracy: 0.83570
# Epoch 187 | Test accuracy: 0.83640
# Epoch 188 | Test accuracy: 0.83770
# Epoch 189 | Test accuracy: 0.83800
# Epoch 190 | Test accuracy: 0.83880
# Epoch 191 | Test accuracy: 0.83940
# Epoch 192 | Test accuracy: 0.84000
# Epoch 193 | Test accuracy: 0.84090
# Epoch 194 | Test accuracy: 0.84160
# Epoch 195 | Test accuracy: 0.84200
# Epoch 196 | Test accuracy: 0.84290
# Epoch 197 | Test accuracy: 0.84360
# Epoch 198 | Test accuracy: 0.84440
# Epoch 199 | Test accuracy: 0.84590
#
#
# The total time spent is 5130.568341016769

# %%
plt.plot(np.arange(num_epochs), accuracies_test)

# %%
current_dict = {'epochs': num_epochs, 'train_losses': train_losses, 'test_accuracies': accuracies_test}
results.update({'SGD': current_dict})

# %%
# save everything onto file
if save_stats: 
    output_folder = os.path.join(os.getcwd(), 'results')  # set the folder
    os.makedirs(output_folder, exist_ok=True)
    fname = output_folder + '/stats_dict_DFW.pkl'
    with open(fname, 'wb') as handle:
        pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
